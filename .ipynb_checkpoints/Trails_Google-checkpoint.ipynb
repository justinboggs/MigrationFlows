# %%
gkey = "AIzaSyCkdwSeOcjszNhV_1lJn0zkuihzAWtmRHs"
import pandas as pd
import requests
import json

# %%
counties_df = pd.read_csv("Median_Home_Price_csvfinal.csv")
counties_df = counties_df.dropna()
counties_df
# Out:
#      State        County Name Median Home Price Q2 2017
# 0       AL     Autauga County                  $142,792
# 1       AL     Baldwin County                  $210,870
# 2       AL     Barbour County                   $94,248
# 3       AL        Bibb County                  $112,903
# 4       AL      Blount County                  $130,775
# ...    ...                ...                       ...
# 3114    WY  Sweetwater County                  $210,047
# 3115    WY       Teton County                  $772,365
# 3116    WY       Uinta County                  $186,429
# 3117    WY    Washakie County                  $172,949
# 3118    WY      Weston County                  $188,206
#
# [3119 rows x 3 columns]

# %%
# create array of counties 
county_list = counties_df["County Name"]
county_list = county_list.dropna()
county_list = county_list.values

county_list
# Out:
# array(['Autauga County', 'Baldwin County', 'Barbour County', ...,
#        'Uinta County', 'Washakie County', 'Weston County'], dtype=object)

# %%
# create array of states, andtest indexing of states list, to be used in build out of for loop 
state_list = counties_df["State"]
state_list = state_list.dropna()
state_list = state_list.values

state_list[0]
# Out:
# 'AL'

# %%
# 1. What are the geocoordinates (latitude and longitude)
target_city = "Autauga County, Alabama"
params = {"address": target_city, "key": gkey}
# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
print("Drill #1: The Geocoordinates of Autauga County, AL")
# Run request
response = requests.get(base_url, params=params)
# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
# Convert to JSON
autauga_county = response.json()
# Extract lat/lng
lat = autauga_county["results"][0]["geometry"]["location"]["lat"]
lng = autauga_county["results"][0]["geometry"]["location"]["lng"]
# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of Autauga County, AL
# Autauga County, Alabama: 32.5791817, -86.49965460000001

# %%
county = "Autauga County"

target_city = f"{county}, Alabama"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# Run request
response = requests.get(base_url, params=params)

# Convert to JSON
county_response = response.json()

# Extract lat/lng
lat = county_response["results"][0]["geometry"]["location"]["lat"]
lng = county_response["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Autauga County, Alabama: 32.5791817, -86.49965460000001

# %%
#state = "AL"
#county = "Autauga County"
#target_county = f"{county}, {state}"
coords = "47.6062095, -122.3320708"

recreations = ["park","trail","mountain","lake"]

params = {
"location": coords,
"types": recreations,
"radius": 10000,
"key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Run request
response = requests.get(base_url, params=params)


# Convert to JSON
county_response = response.json()
print(json.dumps(county_response, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCGwEAAKIYgvce-TCagHmswOzTdVgYqPhxj3o9mv331SGuC_EtFUNEAa0tGxKMA06QGgAhVGUO06msWrbTifH-cig7MoZBeZfQu0YEd_XvlOgPV4C4S_IoeGjlbx0F6ZU5vMl7Jw1rNEuuI3TLAarjAyCcg4xreQFaeaNhqsp-IKYOZXBox0uAPUPXekPU0MnZJrBE-zmY5YVCHy9WU0r_kxoLCw2ip3DwEeJHWRTt

#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.562992,
#                     "lng": -122.3645196
#                 },
#                 "viewport": {
#                     "northeast": {
# ...

# %%
next_page_token= "CsQDuwEAAJxxHgaCo1monASrHz0f0VPgmgu0QRs1Vj6lI-QJ7b24S9r800oGAqbAeRWVHh86H7EnDkk_-hZWAdSOP1iTfziIWxh2ylb1cd5-lQnorRxie8SU4_2VLVrulQ0ET4ClJ0P0eNcV6Xsrm9l7xvOs8q7OJyzF7dd4kK37RI0gWumQy4ipnp4iJ14R50KJEANRBThin21a_lQUaOvENRd_s4Irmafy-J_6JDw70LPMcMVoedgWjtI7EqdxuXvbjEqGW8pZzXi5hjufCzgc_su2pv2OU0k3RrVKOcdHGtyoTUTxBKAW45uNTWy4D5o5ZuIE9Gb0_aCKFtCA0UvAydwgUKA8nZ18U-iKOU7E1kZuTvLWGQvMezmGvfTeo9hWYxrIqTISZZCuZ5qTZbGvkucWGGFMaNldeBpinJlzm9MZJn716CU_sA4fvLEsBpIqI_qoL6mQLnKroa7rMP7FRBXaqP0FMRdUU-odum3shzXU7nER3kZWNtIsTbxV82ap4MD75GI1R_XRMvsrAtHAB36L5RxmxnUcSMf9cqCTO9M7ZYVaWettLdEzP3ixsvm8jnMPwwJkdNrpRlliIodgCvYmAWUSEEAHndmiU5cX3JWqVKiXKfgaFIjmD7CQWj9EFf65jqEdR4qNjPjw"

coords = "47.6062095, -122.3320708"

recreations = ["park","trail","mountain","lake"]

params = {
"location": coords,
"types": recreations,
"radius": 10000,
"key": gkey,
"pagetoken": next_page_token
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Run request
response = requests.get(base_url, params=params)


# Convert to JSON
county_response = response.json()
print(json.dumps(county_response, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.6339092,
#                     "lng": -122.3975575
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.63525388029149,
#                         "lng": -122.3962257697085
#                     },
#                     "southwest": {
#                         "lat": 47.63255591970849,
#                         "lng": -122.3989237302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png",
#             "id": "84be47e609b86e5dbe64a7abbfd9e85c74048805",
#             "name": "Magnolia Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
# ...

# %%
len(county_response["results"])
# Out:
# 20

# %%
# create for loop

# create array of counties 
county_list = counties_df["County Name"]
county_list = county_list.dropna()
county_list = county_list.values

# create array of states 
state_list = counties_df["State"]
state_list = state_list.dropna()
state_list = state_list.values

# create empty list of coordinates 
county_lats = []
county_lng = []

# create base index counter for state
state_index_counter = 0

# begin for loop
for county in county_list:
    
    state = state_list[state_index_counter]
    
    target_county = f"{county}, {state}"

    params = {"address": target_county, "key": gkey}

    # Build URL using the Google Maps API
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    # Run request
    response = requests.get(base_url, params=params)

    # Convert to JSON
    county_response = response.json()

    # Extract lat/lng
    lat = county_response["results"][0]["geometry"]["location"]["lat"]
    lng = county_response["results"][0]["geometry"]["location"]["lng"]

    county_lats.append(lat)
    county_lng.append(lng)
    
    state_index_counter = state_index_counter + 1
    
    print(lat)
# Out:
# 32.5791817
# 30.6010744
# 31.8172896
# 32.9562798
# 34.0145152
# 32.0573536
# 31.6760284
# 33.7701576
# 32.9028048
# 34.1665322
# 32.944392
# 32.0716631
# 31.7002461
# 33.279527
# 33.6261707
# 31.4751172
# 34.7117567
# 31.501571
# 32.8897772
# 31.3066438
# 31.6671872
# 34.2011537
# 31.4645298
# 32.2332138
# 34.5211397
# 32.5647083
# 31.1394734
# 34.0455341
# 33.6871392
# 34.3967457
# 31.0990456
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# ...

# %%
len(county_lats)
# Out:
# 3119

# %%
counties_latlng = counties_df[["State","County Name"]]
counties_latlng
counties_latlng["Latitude"] = county_lats
counties_latlng["Longitude"] = county_lng
counties_latlng
# Out:
#      State        County Name   Latitude   Longitude
# 0       AL     Autauga County  32.579182  -86.499655
# 1       AL     Baldwin County  30.601074  -87.776333
# 2       AL     Barbour County  31.817290  -85.354965
# 3       AL        Bibb County  32.956280  -87.142289
# 4       AL      Blount County  34.014515  -86.499655
# ...    ...                ...        ...         ...
# 3114    WY  Sweetwater County  41.851940 -109.188005
# 3115    WY       Teton County  43.853632 -110.631449
# 3116    WY       Uinta County  41.210740 -110.616892
# 3117    WY    Washakie County  43.834783 -107.703763
# 3118    WY      Weston County  43.927022 -104.472330
#
# [3119 rows x 4 columns]

# %%
# for loop for google api search

# create array of counties 
county_list = counties_df["County Name"]
county_list = county_list.values

# create array of states 
state_list = counties_df["State"]
state_list = state_list.values

# create list of google searches: 
recreation_list = ["Park","Trail","Beach","Ski resort","Mountain","Lake"]

for recreation in recreation_list:
    
    # create base index counter for state
    state_index_counter = 0
    
    length_of_results = []

    # begin for loop
    for county in county_list:

        state = state_list[state_index_counter]
        
        # change to latitude and longitude 
        target_county = f"{county}, {state}"
        
        #change to latitude and longitude 
        params = {
        "location": f"{county}, {state}",
        "types": recreation,
        "radius": 10000,
        "key": gkey
        }

        # Build URL using the Google Maps API
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        # Run request
        response = requests.get(base_url, params=params)

        # Convert to JSON
        county_response = response.json()  

        #append the length of results to the array 
        results_len = len(county_response["results"])
        length_of_results

        # add count to state index 
        state_index_counter = state_index_counter + 1
        
print(length_of_results)
# Out:
# From cffi callback <function _verify_callback at 0x000001D06F56A318>:
# Traceback (most recent call last):
#   File "C:\Users\josep\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 306, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
# ...

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type = "bicycle_store"
seattle_coords = "47.6062095,-122.3320708"
radius = 8000

# rewrite params dict

params = {
    "location": seattle_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3: A Bike Store in Seattle, WA")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

seattle_bikes = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(seattle_bikes, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
print(seattle_bikes["results"][0]["name"])
print(seattle_bikes["results"][0]["vicinity"])
