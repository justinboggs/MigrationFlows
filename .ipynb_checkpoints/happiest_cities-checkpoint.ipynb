# %%
#This is the starter notebook
import pandas as pd

'countyinflow1718.csv'

county_inflow = 'countyinflow1718.csv'

county_outflow = 'countyoutflow1718.csv'

# Read Purchasing File and store into Pandas data frame
outflow_df = pd.read_csv(county_outflow)

inflow_df = pd.read_csv(county_inflow)

#outflow_df = outflow_df[outflow_df['y2_countyname'].str.contains('County Non-migrants','County Total Migration-US and Foreign')]

inflow_df = inflow_df[inflow_df['y1_countyname'].str.contains('County Non-migrants') | inflow_df['y1_countyname'].str.contains('County Total Migration-US and Foreign')]

outflow_df = outflow_df[outflow_df['y2_countyname'].str.contains('County Non-migrants') | outflow_df['y2_countyname'].str.contains('County Total Migration-US and Foreign')]

outflow_df = outflow_df.rename(columns = {"y2_countyname":"outflow_county","y2_state":"outflow_state","n1":"outflow_n1","n2":"outflow_n2","agi_x":"outflow_agi"})


inflow_df = inflow_df.rename(columns = {"y1_countyname":"inflow_county","y1_state":"inflow_state","n1":"inflow_n1","n2":"inflow_n2","agi_y":"inflow_agi"})

county_in_out_df = pd.merge(outflow_df,inflow_df,left_on=["outflow_state","outflow_county"],right_on=["inflow_state","inflow_county"])

del county_in_out_df['y1_statefips_x']

del county_in_out_df['y1_countyfips_x']

del county_in_out_df['y2_statefips_x']

del county_in_out_df['y2_countyfips_x']

del county_in_out_df['y2_statefips_y']

del county_in_out_df['y2_countyfips_y']

del county_in_out_df['y1_statefips_y']

del county_in_out_df['y1_countyfips_y']

county_in_out_df

# county_in_out_df.to_csv("county_in_out.csv")
# Out:
#      outflow_state                                  outflow_county  \
# 0               AL   Autauga County Total Migration-US and Foreign
# 1               AL                     Autauga County Non-migrants
# 2               AL   Baldwin County Total Migration-US and Foreign
# 3               AL                     Baldwin County Non-migrants
# 4               AL   Barbour County Total Migration-US and Foreign
# ...            ...                                             ...
# 6007            WY                       Uinta County Non-migrants
# 6008            WY  Washakie County Total Migration-US and Foreign
# 6009            WY                    Washakie County Non-migrants
# 6010            WY    Weston County Total Migration-US and Foreign
# 6011            WY                      Weston County Non-migrants
#
#       outflow_n1  outflow_n2    agi_x inflow_state  \
# 0           1888        4179    99955           AL
# 1          18028       41008  1143227           AL
# 2           4609        8640   238893           AL
# 3          73765      158376  5421048           AL
# 4            445         914    16473           AL
# ...          ...         ...      ...          ...
# 6007        7077       17251   509964           WY
# 6008         180         350     7868           WY
# 6009        2875        6375   193724           WY
# 6010         162         328     8110           WY
# 6011        2488        5306   158856           WY
#
#                                        inflow_county  inflow_n1  inflow_n2  \
# 0      Autauga County Total Migration-US and Foreign       1925       4386
# 1                        Autauga County Non-migrants      18028      41008
# 2      Baldwin County Total Migration-US and Foreign       6818      13693
# 3                        Baldwin County Non-migrants      73765     158376
# 4      Barbour County Total Migration-US and Foreign        389        839
# ...                                              ...        ...        ...
# 6007                       Uinta County Non-migrants       7077      17251
# 6008  Washakie County Total Migration-US and Foreign        162        351
# 6009                    Washakie County Non-migrants       2875       6375
# 6010    Weston County Total Migration-US and Foreign        155        313
# 6011                      Weston County Non-migrants       2488       5306
#
#         agi_y
# 0      100564
# 1     1143227
# 2      491043
# 3     5421048
# 4       15215
# ...       ...
# 6007   509964
# 6008     8388
# 6009   193724
# 6010     8083
# 6011   158856
#
# [6012 rows x 10 columns]

# %%
happy = county_in_out_df[county_in_out_df['outflow_county'].str.contains("Non-migrants")]
happy = happy.reset_index()
happy
# Out:
#       index outflow_state                  outflow_county  outflow_n1  \
# 0         1            AL     Autauga County Non-migrants       18028
# 1         3            AL     Baldwin County Non-migrants       73765
# 2         5            AL     Barbour County Non-migrants        7176
# 3         7            AL        Bibb County Non-migrants        6054
# 4         9            AL      Blount County Non-migrants       17300
# ...     ...           ...                             ...         ...
# 3001   6003            WY  Sweetwater County Non-migrants       15417
# 3002   6005            WY       Teton County Non-migrants       10727
# 3003   6007            WY       Uinta County Non-migrants        7077
# 3004   6009            WY    Washakie County Non-migrants        2875
# 3005   6011            WY      Weston County Non-migrants        2488
#
#       outflow_n2    agi_x inflow_state                   inflow_county  \
# 0          41008  1143227           AL     Autauga County Non-migrants
# 1         158376  5421048           AL     Baldwin County Non-migrants
# 2          15417   322664           AL     Barbour County Non-migrants
# 3          14005   332129           AL        Bibb County Non-migrants
# 4          41284   982763           AL      Blount County Non-migrants
# ...          ...      ...          ...                             ...
# 3001       34982  1216231           WY  Sweetwater County Non-migrants
# 3002       21227  3408826           WY       Teton County Non-migrants
# 3003       17251   509964           WY       Uinta County Non-migrants
# 3004        6375   193724           WY    Washakie County Non-migrants
# 3005        5306   158856           WY      Weston County Non-migrants
#
#       inflow_n1  inflow_n2    agi_y
# 0         18028      41008  1143227
# 1         73765     158376  5421048
# 2          7176      15417   322664
# 3          6054      14005   332129
# 4         17300      41284   982763
# ...         ...        ...      ...
# 3001      15417      34982  1216231
# 3002      10727      21227  3408826
# 3003       7077      17251   509964
# 3004       2875       6375   193724
# 3005       2488       5306   158856
#
# [3006 rows x 11 columns]

# %%
happy2 = county_in_out_df[county_in_out_df['outflow_county'].str.contains('US and Foreign')]
happy2 = happy2.reset_index()
happy2
# Out:
#       index outflow_state                                    outflow_county  \
# 0         0            AL     Autauga County Total Migration-US and Foreign
# 1         2            AL     Baldwin County Total Migration-US and Foreign
# 2         4            AL     Barbour County Total Migration-US and Foreign
# 3         6            AL        Bibb County Total Migration-US and Foreign
# 4         8            AL      Blount County Total Migration-US and Foreign
# ...     ...           ...                                               ...
# 3001   6002            WY  Sweetwater County Total Migration-US and Foreign
# 3002   6004            WY       Teton County Total Migration-US and Foreign
# 3003   6006            WY       Uinta County Total Migration-US and Foreign
# 3004   6008            WY    Washakie County Total Migration-US and Foreign
# 3005   6010            WY      Weston County Total Migration-US and Foreign
#
#       outflow_n1  outflow_n2   agi_x inflow_state  \
# 0           1888        4179   99955           AL
# 1           4609        8640  238893           AL
# 2            445         914   16473           AL
# 3            450         954   18686           AL
# 4           1148        2459   51327           AL
# ...          ...         ...     ...          ...
# 3001        1084        2322   71652           WY
# 3002        1218        1951  109912           WY
# 3003         485        1033   31788           WY
# 3004         180         350    7868           WY
# 3005         162         328    8110           WY
#
#                                          inflow_county  inflow_n1  inflow_n2  \
# 0        Autauga County Total Migration-US and Foreign       1925       4386
# 1        Baldwin County Total Migration-US and Foreign       6818      13693
# 2        Barbour County Total Migration-US and Foreign        389        839
# 3           Bibb County Total Migration-US and Foreign        376        856
# 4         Blount County Total Migration-US and Foreign       1211       2482
# ...                                                ...        ...        ...
# 3001  Sweetwater County Total Migration-US and Foreign        834       1755
# 3002       Teton County Total Migration-US and Foreign       1188       1798
# 3003       Uinta County Total Migration-US and Foreign        441        959
# 3004    Washakie County Total Migration-US and Foreign        162        351
# 3005      Weston County Total Migration-US and Foreign        155        313
#
#        agi_y
# 0     100564
# 1     491043
# 2      15215
# 3      15189
# 4      52661
# ...      ...
# 3001   43730
# 3002  212532
# 3003   22104
# 3004    8388
# 3005    8083
#
# [3006 rows x 11 columns]

# %%
# Merge two Dataframes on index of both the dataframes
final = happy.merge(happy2, left_index=True, right_index=True)
final.head()
# Out:
#    index_x outflow_state_x             outflow_county_x  outflow_n1_x  \
# 0        1              AL  Autauga County Non-migrants         18028
# 1        3              AL  Baldwin County Non-migrants         73765
# 2        5              AL  Barbour County Non-migrants          7176
# 3        7              AL     Bibb County Non-migrants          6054
# 4        9              AL   Blount County Non-migrants         17300
#
#    outflow_n2_x  agi_x_x inflow_state_x              inflow_county_x  \
# 0         41008  1143227             AL  Autauga County Non-migrants
# 1        158376  5421048             AL  Baldwin County Non-migrants
# 2         15417   322664             AL  Barbour County Non-migrants
# 3         14005   332129             AL     Bibb County Non-migrants
# 4         41284   982763             AL   Blount County Non-migrants
#
#    inflow_n1_x  inflow_n2_x  ...  outflow_state_y  \
# 0        18028        41008  ...               AL
# 1        73765       158376  ...               AL
# 2         7176        15417  ...               AL
# 3         6054        14005  ...               AL
# 4        17300        41284  ...               AL
#
#                                 outflow_county_y outflow_n1_y outflow_n2_y  \
# 0  Autauga County Total Migration-US and Foreign         1888         4179
# 1  Baldwin County Total Migration-US and Foreign         4609         8640
# 2  Barbour County Total Migration-US and Foreign          445          914
# 3     Bibb County Total Migration-US and Foreign          450          954
# 4   Blount County Total Migration-US and Foreign         1148         2459
#
#    agi_x_y  inflow_state_y                                inflow_county_y  \
# 0    99955              AL  Autauga County Total Migration-US and Foreign
# 1   238893              AL  Baldwin County Total Migration-US and Foreign
# 2    16473              AL  Barbour County Total Migration-US and Foreign
# 3    18686              AL     Bibb County Total Migration-US and Foreign
# 4    51327              AL   Blount County Total Migration-US and Foreign
#
#   inflow_n1_y inflow_n2_y  agi_y_y
# 0        1925        4386   100564
# 1        6818       13693   491043
# 2         389         839    15215
# 3         376         856    15189
# 4        1211        2482    52661
#
# [5 rows x 22 columns]

# %%
final = final.drop(columns=['index_x', 'outflow_state_x', 'outflow_county_x', 'outflow_n1_x', 'outflow_n2_x', 'agi_x_x', 'index_y',
                   'outflow_state_y', 'outflow_county_y', 'inflow_state_y', 'inflow_county_y', 'inflow_n2_x', 'outflow_n2_y', 'inflow_n2_y'])
final
# Out:
#      inflow_state_x                 inflow_county_x  inflow_n1_x  agi_y_x  \
# 0                AL     Autauga County Non-migrants        18028  1143227
# 1                AL     Baldwin County Non-migrants        73765  5421048
# 2                AL     Barbour County Non-migrants         7176   322664
# 3                AL        Bibb County Non-migrants         6054   332129
# 4                AL      Blount County Non-migrants        17300   982763
# ...             ...                             ...          ...      ...
# 3001             WY  Sweetwater County Non-migrants        15417  1216231
# 3002             WY       Teton County Non-migrants        10727  3408826
# 3003             WY       Uinta County Non-migrants         7077   509964
# 3004             WY    Washakie County Non-migrants         2875   193724
# 3005             WY      Weston County Non-migrants         2488   158856
#
#       outflow_n1_y  agi_x_y  inflow_n1_y  agi_y_y
# 0             1888    99955         1925   100564
# 1             4609   238893         6818   491043
# 2              445    16473          389    15215
# 3              450    18686          376    15189
# 4             1148    51327         1211    52661
# ...            ...      ...          ...      ...
# 3001          1084    71652          834    43730
# 3002          1218   109912         1188   212532
# 3003           485    31788          441    22104
# 3004           180     7868          162     8388
# 3005           162     8110          155     8083
#
# [3006 rows x 8 columns]

# %%
final['inflow_county_x'] = final['inflow_county_x'].str.rstrip('Non-migrants')
final
# Out:
#      inflow_state_x     inflow_county_x  inflow_n1_x  agi_y_x  outflow_n1_y  \
# 0                AL     Autauga County         18028  1143227          1888
# 1                AL     Baldwin County         73765  5421048          4609
# 2                AL     Barbour County          7176   322664           445
# 3                AL        Bibb County          6054   332129           450
# 4                AL      Blount County         17300   982763          1148
# ...             ...                 ...          ...      ...           ...
# 3001             WY  Sweetwater County         15417  1216231          1084
# 3002             WY       Teton County         10727  3408826          1218
# 3003             WY       Uinta County          7077   509964           485
# 3004             WY    Washakie County          2875   193724           180
# 3005             WY      Weston County          2488   158856           162
#
#       agi_x_y  inflow_n1_y  agi_y_y
# 0       99955         1925   100564
# 1      238893         6818   491043
# 2       16473          389    15215
# 3       18686          376    15189
# 4       51327         1211    52661
# ...       ...          ...      ...
# 3001    71652          834    43730
# 3002   109912         1188   212532
# 3003    31788          441    22104
# 3004     7868          162     8388
# 3005     8110          155     8083
#
# [3006 rows x 8 columns]

# %%
final = final.rename(columns={'inflow_state_x': 'State', 'inflow_county_x': 'County', 'inflow_n1_x': 'Returns Total', 
                             'agi_y_x': 'Total AGI', 'outflow_n1_y': 'Outflow', 'agi_x_y': 'Outflow AGI',
                             'inflow_n1_y': 'Inflow', 'agi_y_y': 'Inflow AGI'})
final
# Out:
#      State              County  Returns Total  Total AGI  Outflow  \
# 0       AL     Autauga County           18028    1143227     1888
# 1       AL     Baldwin County           73765    5421048     4609
# 2       AL     Barbour County            7176     322664      445
# 3       AL        Bibb County            6054     332129      450
# 4       AL      Blount County           17300     982763     1148
# ...    ...                 ...            ...        ...      ...
# 3001    WY  Sweetwater County           15417    1216231     1084
# 3002    WY       Teton County           10727    3408826     1218
# 3003    WY       Uinta County            7077     509964      485
# 3004    WY    Washakie County            2875     193724      180
# 3005    WY      Weston County            2488     158856      162
#
#       Outflow AGI  Inflow  Inflow AGI
# 0           99955    1925      100564
# 1          238893    6818      491043
# 2           16473     389       15215
# 3           18686     376       15189
# 4           51327    1211       52661
# ...           ...     ...         ...
# 3001        71652     834       43730
# 3002       109912    1188      212532
# 3003        31788     441       22104
# 3004         7868     162        8388
# 3005         8110     155        8083
#
# [3006 rows x 8 columns]

# %%
#df['Col3'] = (df['Col2'] <= 1).astype(int)
final['Net Inflow(Outflow)'] = (final['Inflow'] - final['Outflow']).astype(int)
final
# Out:
#      State              County  Returns Total  Total AGI  Outflow  \
# 0       AL     Autauga County           18028    1143227     1888
# 1       AL     Baldwin County           73765    5421048     4609
# 2       AL     Barbour County            7176     322664      445
# 3       AL        Bibb County            6054     332129      450
# 4       AL      Blount County           17300     982763     1148
# ...    ...                 ...            ...        ...      ...
# 3001    WY  Sweetwater County           15417    1216231     1084
# 3002    WY       Teton County           10727    3408826     1218
# 3003    WY       Uinta County            7077     509964      485
# 3004    WY    Washakie County            2875     193724      180
# 3005    WY      Weston County            2488     158856      162
#
#       Outflow AGI  Inflow  Inflow AGI  Net Inflow(Outflow)
# 0           99955    1925      100564                   37
# 1          238893    6818      491043                 2209
# 2           16473     389       15215                  -56
# 3           18686     376       15189                  -74
# 4           51327    1211       52661                   63
# ...           ...     ...         ...                  ...
# 3001        71652     834       43730                 -250
# 3002       109912    1188      212532                  -30
# 3003        31788     441       22104                  -44
# 3004         7868     162        8388                  -18
# 3005         8110     155        8083                   -7
#
# [3006 rows x 9 columns]

# %%
final['Percentage Flow'] = (final['Net Inflow(Outflow)'] / final['Returns Total']).astype(float)
final
# Out:
#      State              County  Returns Total  Total AGI  Outflow  \
# 0       AL     Autauga County           18028    1143227     1888
# 1       AL     Baldwin County           73765    5421048     4609
# 2       AL     Barbour County            7176     322664      445
# 3       AL        Bibb County            6054     332129      450
# 4       AL      Blount County           17300     982763     1148
# ...    ...                 ...            ...        ...      ...
# 3001    WY  Sweetwater County           15417    1216231     1084
# 3002    WY       Teton County           10727    3408826     1218
# 3003    WY       Uinta County            7077     509964      485
# 3004    WY    Washakie County            2875     193724      180
# 3005    WY      Weston County            2488     158856      162
#
#       Outflow AGI  Inflow  Inflow AGI  Net Inflow(Outflow)  Percentage Flow
# 0           99955    1925      100564                   37         0.002052
# 1          238893    6818      491043                 2209         0.029946
# 2           16473     389       15215                  -56        -0.007804
# 3           18686     376       15189                  -74        -0.012223
# 4           51327    1211       52661                   63         0.003642
# ...           ...     ...         ...                  ...              ...
# 3001        71652     834       43730                 -250        -0.016216
# 3002       109912    1188      212532                  -30        -0.002797
# 3003        31788     441       22104                  -44        -0.006217
# 3004         7868     162        8388                  -18        -0.006261
# 3005         8110     155        8083                   -7        -0.002814
#
# [3006 rows x 10 columns]

# %%
final.to_csv('final_data.csv')
