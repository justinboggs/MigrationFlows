# %%
#import dependencies
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
import gmaps
import os
import json
import pprint as pprint

# %%
population_df = pd.read_csv('output_data/final.csv')
sample_df = pd.read_csv('output_data/sample_300.csv')

# %%
population = population_df['Flow(%)']
sample = sample_df['Flow(%)']

# %%
plt.subplot(2, 1, 1)
plt.scatter(range(len(population)), population, label='Population')
plt.scatter(range(len(sample)), sample, label='Sample')
plt.legend()

plt.subplot(2, 1, 2)
plt.hist(population, 20, density=True, alpha=0.7, label='population')
plt.hist(sample, 20, density=True, alpha=0.7, label='sample')
plt.axvline(population.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(sample.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.savefig('output_data/t_test.png')

# %%
stats.ttest_1samp(sample, population.mean())
# Out:
# Ttest_1sampResult(statistic=0.6019516428666937, pvalue=0.5476624965825031)
